# %% [markdown]
# <a href="https://colab.research.google.com/github/ManishaJais/llm_maintenance_summarizer/blob/main/01_generate_synthetic_data_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

drive_data_dir = "/content/drive/MyDrive/LLM_RAG_Learning/project01/data"
os.makedirs(drive_data_dir, exist_ok=True)

print("Created directory:", drive_data_dir)
# Out:
# Created directory: /content/drive/MyDrive/LLM_RAG_Learning/project01/data

# %%
# !ls "/content/drive/MyDrive/LLM_RAG_Learning/project01/data"
# Out:
# maintenance_logs.csv

# %%
import pandas as pd
import os

examples = [
 {
  "log_text": "Shift C: Compressor 1 discharge temperature increased steadily to 140°C. Vibration baseline shifted upward. Oil level slightly below minimum mark.",
  "summary_text": "Compressor overheating likely due to low oil level and rising vibration. Refill oil and inspect bearings."
 },
 {
  "log_text": "Conveyor tail pulley noise louder than normal. Thermal camera shows hotspot at bearing housing. Belt tension appears uneven across width.",
  "summary_text": "Tail pulley bearing overheating and belt tension imbalance. Check bearing and retension belt."
 },
 {
  "log_text": "AG mill feed rate fluctuating between 225–310 tph. Control system attempted corrections but load cell readings unstable.",
  "summary_text": "Feed rate instability caused by noisy load cell data. Inspect load cell calibration and wiring."
 },
 {
  "log_text": "Pump 4 was cavitating intermittently. Suction pressure dropped below design. Operator reported air bubbles visible in sight glass.",
  "summary_text": "Pump cavitation due to air ingress on suction side. Inspect suction pipe for leaks."
 },
 {
  "log_text": "Filter press cycle time increased from 28 min to 44 min. Cake moisture higher than normal. Feed slurry density inconsistent.",
  "summary_text": "Long cycle time and wet cake caused by inconsistent slurry density. Stabilize upstream thickener control."
 },
 {
  "log_text": "Hydraulic press ram speed reduced by 30%. Fluid temperature reached 68°C. Strainer showed significant contamination.",
  "summary_text": "Press slowdown due to hydraulic fluid contamination. Replace fluid and clean strainer."
 },
 {
  "log_text": "Boiler flame instability reported twice during evening shift. Fuel pressure dropped by 15%. Atomizer nozzle partially blocked.",
  "summary_text": "Boiler instability due to blocked atomizer nozzle and low fuel pressure. Clean nozzle and restore pressure."
 },
 {
  "log_text": "Gearbox 2 vibration at 2× running speed increased significantly. Oil splash sampling indicates metallic particles.",
  "summary_text": "Possible gear tooth wear in Gearbox 2. Schedule inspection."
 },
 {
  "log_text": "Cooling tower fan current increased from 16 A to 24 A. Blades show algae build-up. Water quality not controlled.",
  "summary_text": "Blade fouling causing fan overload. Clean blades and improve water treatment."
 },
 {
  "log_text": "Crusher discharge size larger than expected. Operator observed uneven mantle wear. CSS control acting sluggish.",
  "summary_text": "Oversized product due to mantle wear and slow CSS control. Inspect mantle and calibrate CSS."
 },
 {
  "log_text": "Control valve CV-32 oscillating around setpoint. Positioner shows delay. Instrument air pressure borderline low.",
  "summary_text": "Valve oscillation from low air pressure and sluggish positioner. Fix air supply and tune positioner."
 },
 {
  "log_text": "Stack emission opacity increased to 25%. ESP rapping system malfunctioning. Hopper ash level high.",
  "summary_text": "High opacity due to ESP rapping and ash build-up. Restore rapping and empty hopper."
 },
 {
  "log_text": "AG mill liner wear sensors triggered. Noise signature indicates higher impact on shell liners.",
  "summary_text": "Shell liner wear progressing. Plan replacement in next shutdown."
 },
 {
  "log_text": "Electrical panel temperature exceeded 60°C. Cooling fan not operational. Slight burnt smell detected.",
  "summary_text": "Panel overheating from failed fan. Replace fan and check wiring."
 },
 {
  "log_text": "Fuel pump tripped twice on overload. Suction filter partially blocked. Fuel viscosity high in cold conditions.",
  "summary_text": "Pump overload due to filter blockage and high viscosity. Clean filter and improve preheating."
 },
 {
  "log_text": "AG mill discharge pump vibrating intermittently. Shaft alignment off. Bearing housing warmer than normal.",
  "summary_text": "Pump misalignment causing vibration. Realign and inspect bearings."
 },
 {
  "log_text": "Water tank level transmitter showing erratic readings. Moisture detected in transmitter head.",
  "summary_text": "Faulty readings due to moisture ingress. Dry or replace transmitter."
 },
 {
  "log_text": "Bucket elevator jammed twice. Foreign object found in boot. Chain tension low.",
  "summary_text": "Elevator jamming from debris and low chain tension. Clean boot and retension chain."
 },
 {
  "log_text": "Baghouse DP rising steadily. Some bags leaking dust. Pulse cleaning ineffective.",
  "summary_text": "High DP due to damaged bags and poor cleaning. Replace leaking bags."
 },
 {
  "log_text": "Fan 7 axial vibration increased. Soft foot suspected. Mounting bolts unevenly tightened.",
  "summary_text": "Axial vibration due to soft foot. Relevel and tighten mounting bolts."
 },
 {
  "log_text": "Boiler feed pump current increased 18%. Impeller noise suggests erosion. Water quality parameters out of range.",
  "summary_text": "Pump overload likely due to impeller erosion caused by poor water quality."
 },
 {
  "log_text": "Shift B: Motor winding temperature trending upward. Cooling vents blocked with dust.",
  "summary_text": "Motor overheating due to blocked cooling vents. Clean vents."
 },
 {
  "log_text": "Conveyor 5 magnetic separator not removing metallic fines. Magnet strength appears weak.",
  "summary_text": "Ineffective separation due to weak magnet. Recalibrate or replace magnet."
 },
 {
  "log_text": "Steam valve slow to respond. Valve stem friction high. Packing gland too tight.",
  "summary_text": "Valve sluggishness from overtight packing. Adjust packing."
 },
 {
  "log_text": "Pump discharge pressure oscillating. Air entrapped in suction line. Noisy bearings reported.",
  "summary_text": "Pressure oscillation due to air in suction line. Purge air and inspect bearings."
 },
 {
  "log_text": "AG mill power draw reduced unexpectedly. Feed size coarser than normal. Trommel screen partially blocked.",
  "summary_text": "Reduced power draw from coarse feed and blocked screen. Clean screen and stabilize feed."
 },
 {
  "log_text": "Cooling water outlet temperature rising. Heat exchanger fouled with scale.",
  "summary_text": "Poor cooling due to scale buildup. Clean heat exchanger."
 },
 {
  "log_text": "Shift A: Lubrication pump running intermittently. Sight glass shows foamy oil.",
  "summary_text": "Intermittent lubrication due to air in oil. Check seals and aeration."
 },
 {
  "log_text": "Hydraulic system pressure stuck at 110 bar (below 160 bar). Relief valve leaking internally.",
  "summary_text": "Low hydraulic pressure due to relief valve leakage. Repair or replace valve."
 },
 {
  "log_text": "Conveyor belt tracking poorly near head pulley. Skirt rubber worn. Loading point uneven.",
  "summary_text": "Poor tracking due to worn skirting and uneven loading. Replace skirting and correct loading."
 },
 {
  "log_text": "Motor starter tripped twice. Contact resistance high. Contactors worn.",
  "summary_text": "Starter trips caused by worn contactors. Replace contactors."
 },
 {
  "log_text": "Boiler drum level controller overshooting. Level transmitter calibration drifted.",
  "summary_text": "Drum level instability from transmitter drift. Recalibrate transmitter."
 },
 {
  "log_text": "Stack fan vibration spiked suddenly. Coupling misalignment suspected.",
  "summary_text": "Vibration spike due to misaligned coupling. Realign coupling."
 },
 {
  "log_text": "Conveyor 2 tripped due to belt slip. Drive pulley lagging rubber worn.",
  "summary_text": "Belt slip due to worn lagging. Replace pulley lagging."
 },
 {
  "log_text": "Shift C: Steam trap leaking continuously. Condensate line temperature high.",
  "summary_text": "Steam trap failed open. Replace trap."
 },
 {
  "log_text": "Mill lubrication oil filter DP rising. Oil appears dark, contaminated.",
  "summary_text": "High filter DP due to dirty oil. Replace filter and oil."
 },
 {
  "log_text": "Cooling fan 3 making rattling noise. Blade looseness observed.",
  "summary_text": "Rattling caused by loose blades. Tighten or replace blades."
 },
 {
  "log_text": "Pump 7 shaft seal leaking lightly. Drip increasing gradually.",
  "summary_text": "Seal wear causing leakage. Replace shaft seal."
 },
 {
  "log_text": "Turbine governor response lagging. Hydraulic actuator sluggish.",
  "summary_text": "Governor lag caused by actuator sluggishness. Service actuator."
 },
 {
  "log_text": "AG mill sound level unusually low, indicating low impact. Mill likely underfilled.",
  "summary_text": "Low sound suggests underfilling. Increase feed rate."
 },
 {
  "log_text": "Cyclone overflow unusually dilute. Underflow density low. Apex likely worn.",
  "summary_text": "Dilute overflow due to worn apex. Replace cyclone apex."
 },
 {
  "log_text": "Boiler feed pump bearings hot to touch. Lubrication frequency overdue.",
  "summary_text": "Bearing overheating due to missed lubrication. Lubricate immediately."
 },
 {
  "log_text": "Conveyor skirt rubber generating burning smell. Excess friction with belt.",
  "summary_text": "Skirt rubber rubbing belt excessively. Adjust skirt clearance."
 },
 {
  "log_text": "Motor insulation resistance low during IR test. Moisture detected.",
  "summary_text": "Low IR from moisture ingress. Dry motor windings."
 },
 {
  "log_text": "Pump 2 delivering low flow. Impeller clogged with debris.",
  "summary_text": "Low flow due to clogged impeller. Clean impeller."
 },
 {
  "log_text": "Belt weigher reading unstable. Load cell mounting loose.",
  "summary_text": "Unstable weight readings due to loose load cell. Tighten mounting."
 },
 {
  "log_text": "Gearbox input shaft seal leaking. Oil puddle forming.",
  "summary_text": "Seal failure causing oil leak. Replace shaft seal."
 },
 {
  "log_text": "Stack fan current fluctuating ±12%. VFD logs show voltage imbalance.",
  "summary_text": "Current fluctuation from VFD voltage imbalance. Inspect VFD power stage."
 },
 {
  "log_text": "Boiler soot blowing ineffective. Flue gas temperature increased by 20°C.",
  "summary_text": "Ineffective soot blowing causing high flue temperature. Inspect soot blowers."
 },
 {
  "log_text": "Hydraulic cylinder retracts slowly. Internal leakage suspected. Oil temperature elevated.",
  "summary_text": "Slow retract caused by internal cylinder leakage. Replace seals."
 }

]

augmented = []
for i in range(5):
    for ex in examples:
        augmented.append(
            {
                "log_text": f"[Shift {i+1}] " + ex["log_text"],
                "summary_text": ex["summary_text"],
            }
        )

df = pd.DataFrame(augmented)
print(df.head())
print("Total samples:", len(df))

output_dir = "LLM_RAG_Learning/project01/data"
os.makedirs(output_dir, exist_ok=True)
df.to_csv(os.path.join(output_dir, "maintenance_logs.csv"), index=False)
# Out:
#                                             log_text  \
# 0  [Shift 1] Shift C: Compressor 1 discharge temp...
# 1  [Shift 1] Conveyor tail pulley noise louder th...
# 2  [Shift 1] AG mill feed rate fluctuating betwee...
# 3  [Shift 1] Pump 4 was cavitating intermittently...
# 4  [Shift 1] Filter press cycle time increased fr...
#
#                                         summary_text
# 0  Compressor overheating likely due to low oil l...
# 1  Tail pulley bearing overheating and belt tensi...
# 2  Feed rate instability caused by noisy load cel...
# 3  Pump cavitation due to air ingress on suction ...
# 4  Long cycle time and wet cake caused by inconsi...
# Total samples: 250

# %%
# !find /content -maxdepth 4 -type f -name "maintenance_logs.csv"
# Out:
# /content/LLM_RAG_Learning/project01/data/maintenance_logs.csv
